# %%
# %matplotlib inline
import matplotlib
import seaborn as sns
matplotlib.rcParams['savefig.dpi'] = 144

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import base
from sklearn.feature_extraction import DictVectorizer
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.neighbors import NearestNeighbors
from sklearn.linear_model import RidgeCV, LinearRegression, SGDRegressor, Ridge
from sklearn.decomposition import TruncatedSVD
from sklearn.grid_search import GridSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.cross_validation import train_test_split

# %% [markdown]
# # Recommendation Engine

# %% [markdown]
# ## Problem definition and data format
#
# The goal of a recommendation engine is to match items to users that will prefer them.  Since we have a set of previous ratings, we can use them to make guesses about which items a user will rate highest.  In this tutorial, we will cover two ways of doing this:
#
# 1. **Content-based rating:** We can make this guess based only on features of the users or items.
# 1. **Collaborative Rating:** We could also look at ratings of similar users or similar items.
#
# For an example data set, we are using the [MovieLens 10M dataset](http://files.grouplens.org/datasets/movielens/ml-10m.zip).  This contains about 10M ratings for 10k movies by 72k users.  We will be building applications that attempts to present movies that a given user would rate highly.  The following cell will download and extract the data to the `projects/ml-10M100K/` directory.

# %%
# %%bash
# cd projects
# if [ ! -d "ml-10M100K" ]; then
#     wget http://files.grouplens.org/datasets/movielens/ml-10m.zip
#     unzip ml-10m.zip
#     rm ml-10m.zip
# fi
# Out:
# bash: line 1: cd: projects: No such file or directory

# %% [markdown]
# There are three data files that are unpacked.  `movies.dat` contains movie IDs, titles, and categories.  `tags.dat` contains a list of tag applications; each line representing the application of a single tag to a movie by a user.  Finally, `ratings.dat` contains the ratings of the movies by the users.
#
# Each of these files are in a custom format, with fields separated by `::`.  They're easy enough to parse with Python string processing.

# %%
def parse_movie_line(l):
    id_, title, cats = l.strip().split('::')
    return {'id': int(id_), 'title': title, 'year': int(title.rsplit(' ')[-1][1:-1]), 
            'categories': cats.split('|')}

with open('ml-10M100K/movies.dat', 'r') as f:
    df = pd.DataFrame([parse_movie_line(l) for l in f]).set_index('id')

df.head()
# Out:
#                                            categories  \
# id
# 1   [Adventure, Animation, Children, Comedy, Fantasy]
# 2                      [Adventure, Children, Fantasy]
# 3                                   [Comedy, Romance]
# 4                            [Comedy, Drama, Romance]
# 5                                            [Comedy]
#
#                                  title  year
# id
# 1                     Toy Story (1995)  1995
# 2                       Jumanji (1995)  1995
# 3              Grumpier Old Men (1995)  1995
# 4             Waiting to Exhale (1995)  1995
# 5   Father of the Bride Part II (1995)  1995

# %%
def parse_tag_line(l):
    uid, mid, tag, time = l.strip().split('::')
    return {'user_id': int(uid), 'movie_id': int(mid), 'tag': tag}

with open('ml-10M100K/tags.dat', 'r') as f:
    df_tags = pd.DataFrame([parse_tag_line(l) for l in f])

df_tags.head()
# Out:
#    movie_id              tag  user_id
# 0      4973       excellent!       15
# 1      1747         politics       20
# 2      1747           satire       20
# 3      2424  chick flick 212       20
# 4      2424            hanks       20

# %%
def parse_rating_line(l):
    uid, mid, rating, time = l.strip().split('::')
    return {'user_id': int(uid), 'movie_id': int(mid), 'rating': float(rating)}

with open('ml-10M100K/ratings.dat', 'r') as f:
    df_ratings = pd.DataFrame([parse_rating_line(l) for l in f])

df_ratings.head()
# Out:
#    movie_id  rating  user_id
# 0       122     5.0        1
# 1       185     5.0        1
# 2       231     5.0        1
# 3       292     5.0        1
# 4       316     5.0        1

# %% [markdown]
# ## Feature engineering
#
# We will start with content modeling, based on the movie categories.  If a user rated a bunch of Adventure films highly, a simple scheme would be to recommend more Adventure films.  Of coure, many users may like several genres of movies, so we need a way to represent categories beyond just the string representing the favorite.
#
# The first approach for vectorizing the categories might be to assign numbers to each of the categories.  For example, we could say *Adventure* = 1, *Drama* = 2, *Comedy* = 3, and so on.  This approach, however, signals that there is some order to these genres.  This mapping would suggest that *Drama* = (*Adventure* + *Comedy*)/2, which isn't meaningful.  We don't want a movie that is an *Adventure Comedy* to have the same feature as a *Drama*.
#
# Instead, we need to recognize that genre is a categorical variable, and thus should be encoded with one-hot encoding.  Essentially, this give each genre its own dimension in feature space.  Our *Adventure Comedy* movie will be located along both the *Adventure* and *Comedy* axes, but at 0 along the *Drama* axis.
#
# We will use *Scikit Learn's* transformers to do this conversion.  We don't know the categories *a priori*, as we did with the days of the week, so we will use the `DictVectorizer` to help us.  This transformer takes in a list of dictionaries.  Each key in the dictionaries gets mapped to a column, and the values for those keys are placed in the appropriate column.  Columns for keys that are not present in a particular row are filled with zeros.
#
# In order to use this, we need to transform our list of genres in to a dictionary, with values of one.

# %%
class DictEncoder(base.BaseEstimator, base.TransformerMixin):
    
    def __init__(self, col):
        self.col = col
    
    def fit(self, X, y=None):
        return self
    
    def transform(self, X):
        
        def to_dict(l):
            try:
                return {x: 1 for x in l}
            except TypeError:
                return {}
        
        return X[self.col].apply(to_dict)

# %% [markdown]
# Handling each transformer manually quickly gets tedious and error-prone. Scikit Learn comes to the rescue with pipelines. Pipelines take a series of transformers and (optionally) an estimator. A pipeline acts as an estimator itself. When it is fit, it fits the first transformer, transforms with the first transformer, uses that value to fit the second transformer, transforms with the second transformer, etc., until finally fitting the estimator. When predict is called on the pipeline, it sends the feature matrix through each of the transformers, before finally calling predict on the estimator.

# %% [markdown]
# This pipeline helps us chain transformers together.  Since the pipeline doesn't end in an estimator, it acts as a transformer instead.

# %%
cat_pipe = Pipeline([('encoder', DictEncoder('categories')),
                     ('vectorizer', DictVectorizer())])
features = cat_pipe.fit_transform(df)
features
# Out:
# <10681x20 sparse matrix of type '<type 'numpy.float64'>'
# 	with 21564 stored elements in Compressed Sparse Row format>

# %% [markdown]
# The `DictVectorizer` returns a sparse matrix.  This allows efficient operations even on high-dimensional data.

# %% [markdown]
# ## Nearest Neighbors
#
# Now that we have a way to describe a movie, we want to be able to find other movies that are nearby in feature space.  This is the **nearest neighbors** problem, and Scikit Learn provides a class to handle this.
#
# When the `NearestNeighbors` object is fit, it records all of the rows in such a way that it can efficiently look through them to find which is nearest to one queried later.  The `NearestNeighbors` assumes that the closest points are the ones for which the [Minkowski Distance](https://en.wikipedia.org/wiki/Minkowski_distance) is minimized.  That is, if we have two rows of our feature vector $X_{i\cdot}$ and $X_{j\cdot}$, it minimizes
# $$ \|X_{i\cdot} - X_{j\cdot}\|_p^p = \sum_k \left(X_{ik} - X_{jk}\right)^p $$
# By default, it computes $p=2$, which is the [Euclidean distance](https://en.wikipedia.org/wiki/Euclidean_distance).

# %% [markdown]
# ![KNN](../images/KnnClassification.svg)

# %%
nn = NearestNeighbors(n_neighbors=20).fit(features)

# %% [markdown]
# We will discuss how to measure performance of these models later, but for now we will just eyeball the results.  We'll pick out two movies as test cases.  *Toy Story* happens to be the first movie in the data set.  *Dr. Strangelove* is a favorite of the author.

# %%
df.iloc[[0, 737]]
# Out:
#                                             categories  \
# id
# 1    [Adventure, Animation, Children, Comedy, Fantasy]
# 750                                      [Comedy, War]
#
#                                                  title  year
# id
# 1                                     Toy Story (1995)  1995
# 750  Dr. Strangelove or: How I Learned to Stop Worr...  1964

# %% [markdown]
# The results for *Toy Story* are reasonable.  All of the movies are animated children's movies, and *Toy Story 2* shows up.  But by relying only on the genres, we are unable to select Pixar movies specifically, for example.

# %%
dists, indices = nn.kneighbors(features[0])
df.iloc[indices[0]]
# Out:
#                                               categories  \
# id
# 26662  [Adventure, Animation, Children, Comedy, Fantasy]
# 1      [Adventure, Animation, Children, Comedy, Fantasy]
# 47124  [Adventure, Animation, Children, Comedy, Fantasy]
# 45074  [Adventure, Animation, Children, Comedy, Fantasy]
# 53121  [Adventure, Animation, Children, Comedy, Fantasy]
# 2294   [Adventure, Animation, Children, Comedy, Fantasy]
# 4016   [Adventure, Animation, Children, Comedy, Fantasy]
# 3114   [Adventure, Animation, Children, Comedy, Fantasy]
# 3754   [Adventure, Animation, Children, Comedy, Fantasy]
# 2116           [Adventure, Animation, Children, Fantasy]
# 6377            [Adventure, Animation, Children, Comedy]
# 5672           [Adventure, Animation, Children, Fantasy]
# 36397  [Adventure, Animation, Children, Comedy, Fanta...
# 5218            [Adventure, Animation, Children, Comedy]
# 4306   [Adventure, Animation, Children, Comedy, Fanta...
# 1848              [Adventure, Children, Comedy, Fantasy]
# 48159           [Adventure, Animation, Children, Comedy]
# 1881           [Adventure, Animation, Children, Fantasy]
# 48414           [Adventure, Animation, Children, Comedy]
# 6350           [Adventure, Animation, Children, Fantasy]
#
#                                                    title  year
# id
# 26662  Kiki's Delivery Service (Majo no takkyûbin) (1...  1989
# 1                                       Toy Story (1995)  1995
# 47124                              Ant Bully, The (2006)  2006
# 45074                                   Wild, The (2006)  2006
# 53121                             Shrek the Third (2007)  2007
# 2294                                         Antz (1998)  1998
# 4016                    Emperor's New Groove, The (2000)  2000
# 3114                                  Toy Story 2 (1999)  1999
# 3754      Adventures of Rocky and Bullwinkle, The (2000)  2000
# 2116                       Lord of the Rings, The (1978)  1978
# 6377                                 Finding Nemo (2003)  2003
# 5672   Pokemon 4 Ever (a.k.a. Pokémon 4: The Movie) (...  2002
# 36397                                     Valiant (2005)  2005
# 5218                                      Ice Age (2002)  2002
# 4306                                        Shrek (2001)  2001
# 1848                               Borrowers, The (1997)  1997
# 48159                             Everyone's Hero (2006)  2006
# 1881                            Quest for Camelot (1998)  1998
# 48414                                 Open Season (2006)  2006
# 6350   Castle in the Sky (Tenkû no shiro Rapyuta) (1986)  1986

# %% [markdown]
# This limitation is more apparent when looking a movies similar to *Dr. Strangelove*.  We get all the *War Comedy* movies, but that doesn't mean that they're similar to *Dr. Strangelove*.  While the author has never seen *The Wackiest Ship in the Army*, he is pretty sure it is of a rather different tone.

# %%
dists, indices = nn.kneighbors(features[737])
df.iloc[indices[0]]
# Out:
#           categories                                              title  year
# id
# 1663   [Comedy, War]                                     Stripes (1981)  1981
# 1078   [Comedy, War]                                     Bananas (1971)  1971
# 63810  [Comedy, War]             When Willie Comes Marching Home (1950)  1950
# 7292   [Comedy, War]                                Best Defense (1984)  1984
# 750    [Comedy, War]  Dr. Strangelove or: How I Learned to Stop Worr...  1964
# 7104   [Comedy, War]                                        1941 (1979)  1979
# 1445   [Comedy, War]                               McHale's Navy (1997)  1997
# 6561   [Comedy, War]                      Mouse That Roared, The (1959)  1959
# 5789   [Comedy, War]                         All the Queen's Men (2001)  2001
# 4802   [Comedy, War]                         Operation Petticoat (1959)  1959
# 157    [Comedy, War]                              Canadian Bacon (1995)  1995
# 4349   [Comedy, War]                                    Catch-22 (1970)  1970
# 473    [Comedy, War]                             In the Army Now (1994)  1994
# 5801   [Comedy, War]  Russians Are Coming, the Russians Are Coming, ...  1966
# 3049   [Comedy, War]                           How I Won the War (1967)  1967
# 7159   [Comedy, War]                         Two Men Went to War (2003)  2003
# 9001   [Comedy, War]              Wackiest Ship in the Army, The (1960)  1960
# 3022   [Comedy, War]                                General, The (1927)  1927
# 2897   [Comedy, War]        And the Ship Sails On (E la nave va) (1983)  1983
# 3968        [Comedy]                                   Bedazzled (2000)  2000

# %% [markdown]
# ## Tag Data
#
# The problem is that we're only getting 20 bits of data about each movie from the categories.  We have much more information in the user-applied tags, though, so let's bring that to bear.
#
# As a reminder, the tag data is stored one tag application per row.

# %%
df_tags.head()
# Out:
#    movie_id              tag  user_id
# 0      4973       excellent!       15
# 1      1747         politics       20
# 2      1747           satire       20
# 3      2424  chick flick 212       20
# 4      2424            hanks       20

# %% [markdown]
# We want all tags for each movie, so we group by the movie_id and get a list of tags.

# %%
all_tags = df_tags.groupby('movie_id')['tag'].apply(lambda x: x.tolist())
all_tags.head()
# Out:
# movie_id
# 1    [Pixar, Pixar, Pixar, animation, Pixar, animat...
# 2    [For children, game, animals, Joe Johnston, Ro...
# 3    [Funniest Movies, comedinha de velhinhos engra...
# 4                                         [girl movie]
# 5    [steve martin, pregnancy, remake, steve martin...
# Name: tag, dtype: object

# %% [markdown]
# The equivalent of a SQL `join` statement in Pandas is the `merge()` method.  We specify a left join, to keep movies without any tags, and indicate rows should be matched by index, which is the movie_id.

# %%
df = df.merge(all_tags.to_frame(), left_index=True, right_index=True, how='left')
df.head()
# Out:
#                                            categories  \
# id
# 1   [Adventure, Animation, Children, Comedy, Fantasy]
# 2                      [Adventure, Children, Fantasy]
# 3                                   [Comedy, Romance]
# 4                            [Comedy, Drama, Romance]
# 5                                            [Comedy]
#
#                                  title  year  \
# id
# 1                     Toy Story (1995)  1995
# 2                       Jumanji (1995)  1995
# 3              Grumpier Old Men (1995)  1995
# 4             Waiting to Exhale (1995)  1995
# 5   Father of the Bride Part II (1995)  1995
#
#                                                   tag
# id
# 1   [Pixar, Pixar, Pixar, animation, Pixar, animat...
# 2   [For children, game, animals, Joe Johnston, Ro...
# 3   [Funniest Movies, comedinha de velhinhos engra...
# 4                                        [girl movie]
# 5   [steve martin, pregnancy, remake, steve martin...

# %% [markdown]
# We'll use the same sort of pipeline to one-hot encode the tags.  (It might be better to use an alternative encoding that accounts for the number of times each tag was applied.)  Then, a `FeatureUnion` can join the two one-hot encoded matrices.

# %%
tag_pipe = Pipeline([('encoder', DictEncoder('tag')),
                     ('vectorizer', DictVectorizer())])
union = FeatureUnion([('categories', cat_pipe),
                      ('tags', tag_pipe)])

# %%
features = union.fit_transform(df)
features
# Out:
# <10681x16549 sparse matrix of type '<type 'numpy.float64'>'
# 	with 92719 stored elements in Compressed Sparse Row format>

# %% [markdown]
# Over 16k features!

# %%
nn = NearestNeighbors(n_neighbors=20).fit(features)

# %% [markdown]
# With the tags, we now clearly pick out *Toy Story 2* as the most similar to *Toy Story*.  But the rest seem worse.  We're not getting any of the Pixar movies, for instance.

# %%
dists, indices = nn.kneighbors(features[0])
df.iloc[indices[0]]
# Out:
#                                               categories  \
# id
# 1      [Adventure, Animation, Children, Comedy, Fantasy]
# 3114   [Adventure, Animation, Children, Comedy, Fantasy]
# 1064                       [Animation, Children, Comedy]
# 5109                    [Adventure, Animation, Children]
# 3759                      [Animation, Children, Musical]
# 2043                      [Adventure, Children, Fantasy]
# 32153          [Adventure, Animation, Children, Fantasy]
# 2142                       [Animation, Children, Comedy]
# 3945                    [Adventure, Animation, Children]
# 48159           [Adventure, Animation, Children, Comedy]
# 7058                                            [Comedy]
# 8525                                  [Children, Comedy]
# 126                       [Adventure, Children, Fantasy]
# 56                        [Adventure, Children, Fantasy]
# 4057                       [Adventure, Children, Comedy]
# 5672           [Adventure, Animation, Children, Fantasy]
# 6265                                            [Comedy]
# 8934                       [Animation, Children, Comedy]
# 2015                         [Children, Comedy, Fantasy]
# 2566                               [Animation, Children]
#
#                                                    title  year  \
# id
# 1                                       Toy Story (1995)  1995
# 3114                                  Toy Story 2 (1999)  1999
# 1064              Aladdin and the King of Thieves (1996)  1996
# 5109                         Return to Never Land (2002)  2002
# 3759                           Fun and Fancy Free (1947)  1947
# 2043           Darby O'Gill and the Little People (1959)  1959
# 32153                          Once Upon a Forest (1993)  1993
# 2142          American Tail: Fievel Goes West, An (1991)  1991
# 3945                           Digimon: The Movie (2000)  2000
# 48159                             Everyone's Hero (2006)  2006
# 7058                             Life with Father (1947)  1947
# 8525                          Ugly Dachshund, The (1966)  1966
# 126                    NeverEnding Story III, The (1994)  1994
# 56                        Kids of the Round Table (1995)  1995
# 4057                                   Kids World (2000)  2000
# 5672   Pokemon 4 Ever (a.k.a. Pokémon 4: The Movie) (...  2002
# 6265                                Head of State (2003)  2003
# 8934                                  Bebe's Kids (1992)  1992
# 2015                 Absent Minded Professor, The (1961)  1961
# 2566                             Doug's 1st Movie (1999)  1999
#
#                                                      tag
# id
# 1      [Pixar, Pixar, Pixar, animation, Pixar, animat...
# 3114   [toys, Pixar, Pixar, Disney, Tom Hanks, sequel...
# 1064         [Cartoon, Dan Castelanetta, comedy, family]
# 5109   [Disney, Disney animated feature, Peter Pan, avi]
# 3759                  [Disney, animation, erlend's DVDs]
# 2043                                            [Disney]
# 32153                                                NaN
# 2142                                           [classic]
# 3945                                         [very good]
# 48159                                                NaN
# 7058                           [family, classic, family]
# 8525                                            [Disney]
# 126                                                  NaN
# 56                                                   NaN
# 4057                                                 NaN
# 5672                                            [decent]
# 6265                                        [funny, avi]
# 8934                                                 NaN
# 2015                            [Disney, Disney studios]
# 2566                                            [Disney]

# %% [markdown]
# The problem becomes more clear looking at *Dr. Strangelove*.  *The Mouse that Roared* is a good pick, but most of the rest have no tags.  The problem is that the tag space is so large, and so sparsely populated, that even similar movies will have very few overlapping tags.  As a result, movies with no tags end up being the closest to most movies.

# %%
dists, indices = nn.kneighbors(features[737])
df.iloc[indices[0]]
# Out:
#           categories                                              title  year  \
# id
# 750    [Comedy, War]  Dr. Strangelove or: How I Learned to Stop Worr...  1964
# 6561   [Comedy, War]                      Mouse That Roared, The (1959)  1959
# 5231        [Comedy]                             Road to Morocco (1942)  1942
# 473    [Comedy, War]                             In the Army Now (1994)  1994
# 7159   [Comedy, War]                         Two Men Went to War (2003)  2003
# 5780        [Comedy]                                   Polyester (1981)  1981
# 5801   [Comedy, War]  Russians Are Coming, the Russians Are Coming, ...  1966
# 9001   [Comedy, War]              Wackiest Ship in the Army, The (1960)  1960
# 63810  [Comedy, War]             When Willie Comes Marching Home (1950)  1950
# 3049   [Comedy, War]                           How I Won the War (1967)  1967
# 8380        [Comedy]                                 Father Hood (1993)  1993
# 8238        [Comedy]                              Little Murders (1971)  1971
# 8331        [Comedy]                 Man Who Came to Dinner, The (1942)  1942
# 8259        [Comedy]                                      Hooper (1978)  1978
# 8425        [Comedy]                         Meet the Applegates (1991)  1991
# 834         [Comedy]                                  Phat Beach (1996)  1996
# 870         [Comedy]                                Gone Fishin' (1997)  1997
# 2151        [Comedy]                  Gods Must Be Crazy II, The (1989)  1989
# 2584        [Comedy]                                     Foolish (1999)  1999
# 8120        [Comedy]                                 29th Street (1991)  1991
#
#                                                      tag
# id
# 750    [Kubrick, classic, nuclear war, Stanley Kubric...
# 6561              [anti-war, nuclear weapons, satirical]
# 5231          [National Film Registry, AFI 100 (Laughs)]
# 473                                                  NaN
# 7159                                                 NaN
# 5780    [biting, campy, humorous, irreverent, satirical]
# 5801                                                 NaN
# 9001                                                 NaN
# 63810                                                NaN
# 3049                                                 NaN
# 8380                                                 NaN
# 8238                                                 NaN
# 8331                                                 NaN
# 8259                                                 NaN
# 8425                                                 NaN
# 834                                                  NaN
# 870                                                  NaN
# 2151                                                 NaN
# 2584                                                 NaN
# 8120                                                 NaN

# %% [markdown]
# ## Dimensional Reduction
#
# We don't actually expect there to be 16k different concepts expressed in the tags.  Rather, several tags may be associated with a single underlying concept.  In the above, we can see tags for *animation* and *cartoon*, for example.

# %% [markdown]
# ![Compression](../images/map_compression.png)

# %% [markdown]
# There are several methods of **dimensional reduction** that attempt to pull out a lower-dimensional structure.  We'll be using Truncated Singular Value Decomposition (SVD), which works well with sparse matrices.  (Other methods include PCA, NMF, etc.)  SVD attempts to find orthogonal directions within feature space, along which the feature matrix has the most variation.  Recall that for $X$, an $n \times p$ feature matrix, we have the [Singular Value Decomposition](https://en.wikipedia.org/wiki/Singular_value_decomposition) with
#
# $$ X = U \Sigma V^T $$
#
# where $U$ is a unitary $n \times n$ matrix, $\Sigma$ is a diagonal $n \times p$ matrix, and $V$ is a unitary $p \times p$ matrix.  With this decomposition, we can then truncate the diagonal matrix $\Sigma$ to include only the $m$ dimensions with the most variation.
#
# Our choice of $m=100$ seems reasonable, but can be tuned to adjust the sensitivity to the tags.

# %% [markdown]
# ![SVD](../images/GaussianScatterPCA.svg)

# %%
tag_pipe = Pipeline([('encoder', DictEncoder('tag')),
                     ('vectorizer', DictVectorizer()),
                     ('svd', TruncatedSVD(n_components=100))])
union = FeatureUnion([('categories', cat_pipe),
                      ('tags', tag_pipe)])

# %%
features = union.fit_transform(df)
features
# Out:
# <10681x120 sparse matrix of type '<type 'numpy.float64'>'
# 	with 783464 stored elements in Compressed Sparse Row format>

# %%
nn = NearestNeighbors(n_neighbors=20).fit(features)
nn.fit(features)
# Out:
# NearestNeighbors(algorithm='auto', leaf_size=30, metric='minkowski',
#          metric_params=None, n_jobs=1, n_neighbors=20, p=2, radius=1.0)

# %% [markdown]
# Now we seem to be getting mostly Disney movies for *Toy Story*, which seems reasonable.

# %%
dists, indices = nn.kneighbors(features[0])
df.iloc[indices[0]]
# Out:
#                                               categories  \
# id
# 1      [Adventure, Animation, Children, Comedy, Fantasy]
# 3114   [Adventure, Animation, Children, Comedy, Fantasy]
# 2355            [Adventure, Animation, Children, Comedy]
# 595     [Animation, Children, Fantasy, Musical, Romance]
# 4016   [Adventure, Animation, Children, Comedy, Fantasy]
# 5444                               [Animation, Children]
# 1907     [Adventure, Animation, Children, Comedy, Drama]
# 45517             [Animation, Children, Comedy, Fantasy]
# 2080     [Animation, Children, Comedy, Musical, Romance]
# 2384                                  [Children, Comedy]
# 1025             [Animation, Children, Fantasy, Musical]
# 1282             [Animation, Children, Fantasy, Musical]
# 40339  [Action, Adventure, Animation, Children, Comed...
# 2294   [Adventure, Animation, Children, Comedy, Fantasy]
# 596              [Animation, Children, Fantasy, Musical]
# 588    [Adventure, Animation, Children, Comedy, Musical]
# 31687                              [Animation, Children]
# 5218            [Adventure, Animation, Children, Comedy]
# 2137                               [Animation, Children]
# 33615           [Adventure, Animation, Children, Comedy]
#
#                                   title  year  \
# id
# 1                      Toy Story (1995)  1995
# 3114                 Toy Story 2 (1999)  1999
# 2355               Bug's Life, A (1998)  1998
# 595         Beauty and the Beast (1991)  1991
# 4016   Emperor's New Groove, The (2000)  2000
# 5444               Lilo & Stitch (2002)  2002
# 1907                       Mulan (1998)  1998
# 45517                       Cars (2006)  2006
# 2080          Lady and the Tramp (1955)  1955
# 2384       Babe: Pig in the City (1998)  1998
# 1025     Sword in the Stone, The (1963)  1963
# 1282                    Fantasia (1940)  1940
# 40339             Chicken Little (2005)  2005
# 2294                        Antz (1998)  1998
# 596                    Pinocchio (1940)  1940
# 588                      Aladdin (1992)  1992
# 31687     Pooh's Heffalump Movie (2005)  2005
# 5218                     Ice Age (2002)  2002
# 2137             Charlotte's Web (1973)  1973
# 33615                 Madagascar (2005)  2005
#
#                                                      tag
# id
# 1      [Pixar, Pixar, Pixar, animation, Pixar, animat...
# 3114   [toys, Pixar, Pixar, Disney, Tom Hanks, sequel...
# 2355   [talking animals, kid flick, Pixar, Pixar, Pix...
# 595    [fairy tale, Disney, Disney, Disney, animated ...
# 4016   [Disney, G, okay, Disney, funny, Disney, almos...
# 5444   [Disney, Disney, Cute!, DIVX, redemption, Bear...
# 1907   [2, fabulous, walt disney, Disney, disney was ...
# 45517  [Pixar, actually funny, instills good moral va...
# 2080   [children, dogs, romantic, Animation, Children...
# 2384   [animation, babe, children, comedy, pg, encant...
# 1025   [Animation, animation, ytutyki, Disney, ENJOYA...
# 1282   [Disney, Disney, Disney, Disney, May 1, Nation...
# 40339  [Zach Braff, Children, erlend's DVDs, Disney, ...
# 2294   [talking animals, Pixar, Adventure, pixar NO d...
# 596    [Disney, Disney, National Film Registry, pixar...
# 588    [Disney, Disney, DVD Collection, want to own, ...
# 31687  [Disney, animation, erlend's DVDs, Pooh, Disne...
# 5218   [talking animals, animated, Disney, own it, Ma...
# 2137   [E.B. White, excellent for kids, animation, fu...
# 33615  [anthropomorphic, dreams, freedom, island, zoo...

# %% [markdown]
# Now, the algorithm finds movies like *The Great Dictator* and *MASH*, which are fairly similar in message to *Dr. Strangelove*.  It also finds *Full Metal Jacket*, another Stanley Kubrick war movie, albeit with a very different tone.

# %%
dists, indices = nn.kneighbors(features[737])
df.iloc[indices[0]]
# Out:
#                         categories  \
# id
# 750                  [Comedy, War]
# 1247      [Comedy, Drama, Romance]
# 1394                      [Comedy]
# 910                [Comedy, Crime]
# 1285                      [Comedy]
# 1281          [Comedy, Drama, War]
# 5060          [Comedy, Drama, War]
# 922    [Drama, Film-Noir, Romance]
# 3629  [Adventure, Comedy, Romance]
# 3099             [Comedy, Romance]
# 6807                      [Comedy]
# 2599                      [Comedy]
# 4361             [Comedy, Romance]
# 1222                  [Drama, War]
# 3462             [Comedy, Romance]
# 3504               [Comedy, Drama]
# 1292               [Comedy, Drama]
# 3022                 [Comedy, War]
# 947                       [Comedy]
# 1079               [Comedy, Crime]
#
#                                                   title  year  \
# id
# 750   Dr. Strangelove or: How I Learned to Stop Worr...  1964
# 1247                               Graduate, The (1967)  1967
# 1394                             Raising Arizona (1987)  1987
# 910                             Some Like It Hot (1959)  1959
# 1285                                    Heathers (1989)  1989
# 1281                         Great Dictator, The (1940)  1940
# 5060                       M*A*S*H (a.k.a. MASH) (1970)  1970
# 922       Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)  1950
# 3629                              Gold Rush, The (1925)  1925
# 3099                                     Shampoo (1975)  1975
# 6807          Monty Python's The Meaning of Life (1983)  1983
# 2599                                    Election (1999)  1999
# 4361                                     Tootsie (1982)  1982
# 1222                           Full Metal Jacket (1987)  1987
# 3462                                Modern Times (1936)  1936
# 3504                                     Network (1976)  1976
# 1292                                 Being There (1979)  1979
# 3022                                General, The (1927)  1927
# 947                               My Man Godfrey (1936)  1936
# 1079                        Fish Called Wanda, A (1988)  1988
#
#                                                     tag
# id
# 750   [Kubrick, classic, nuclear war, Stanley Kubric...
# 1247  [Simon & Garfunkel soundtrack, Simon and Garfu...
# 1394  [Arizona, coen bros, Cult classic, Coen Brothe...
# 910   [romantic comedy, black and white, classic, Co...
# 1285  [ADOLESCENCE IS HELL, high school, library, sn...
# 1281  [black and white, do kina, Chaplin, Nazis, amn...
# 5060  [satire, Vietnam War, great soundtrack, Nation...
# 922   [AFI 100, Emerson must see, Hollywood, Billy W...
# 3629  [black and white, mining, Alaska, amnesia, dan...
# 3099  [Oscar (Best Supporting Actress), biting, irre...
# 6807  [Gilliam, Monty Python, Nudity (Topless - Brie...
# 2599  [black comedy, high school, DVD, Zim, very fun...
# 4361  [AFI 100, men in drag, glbt, National Film Reg...
# 1222  [Stanley Kubrick, Vietnam War, war, Vietnam, o...
# 3462  [black and white, close to perfect, factory, a...
# 3504  [ohsoso, journalism, National Film Registry, O...
# 1292  [subtle, television, Oscar (Best Supporting Ac...
# 3022  [black and white, trains, 19th century, acroba...
# 947   [butler, homeless, screwball, National Film Re...
# 1079  [VHS, fish, blindfold, Jamie Lee Curtis, John ...

# %% [markdown]
# We can examine the directions in feature space that the SVD picked out.  Here, we print the top ten tags associated with each dimension of the SVD.  We can see dimensions corresponding to classic movies, sci-fi franchises, comedies, and movies adapted from books.  (Note that the SVD has found that "based on a book", "adapted from:book", and "based on book" are all associated with each other.)

# %%
svd = tag_pipe.named_steps['svd']
vect = tag_pipe.named_steps['vectorizer']
[", ".join([vect.feature_names_[i] for i in c.argsort()[:-10:-1]])
 for c in svd.components_]
# Out:
# ["Tumey's DVDs, imdb top 250, erlend's DVDs, classic, dvd, seen more than once, R, based on a book, National Film Registry",
#  'R, ClearPlay, Nudity (Topless), movie to see, less than 300 ratings, Nudity (Topless - Brief), owned, based on a book, seen at the cinema',
#  "seen more than once, 70mm, action, seen at the cinema, dvd, Futuristmovies.com, franchise, sci-fi, Eric's Dvds",
#  'less than 300 ratings, based on a book, National Film Registry, adapted from:book, classic, 70mm, AFI 100, movie to see, AFI 100 (Cheers)',
#  'less than 300 ratings, stylized, atmospheric, tense, 70mm, Criterion, quirky, humorous, seen more than once',
#  'based on a book, adapted from:book, stylized, atmospheric, Criterion, disturbing, based on book, tense, Nudity (Topless)',
#  'comedy, quirky, funny, humorous, seen more than once, satirical, classic, irreverent, witty',
#  "Tumey's DVDs, less than 300 ratings, Bibliothek, based on a book, adapted from:book, movie to see, Eric's Dvds, funny, own",
#  'movie to see, imdb top 250, National Film Registry, tense, atmospheric, owned, dvd, AFI 100, overrated',
#  'Nudity (Topless), tense, murder, Nudity (Topless - Brief), National Film Registry, quirky, humorous, visceral, AFI 100',
#  "Nudity (Topless), erlend's DVDs, Nudity (Topless - Brief), drama, less than 300 ratings, Owned, overrated, Eric's Dvds, dvd",
#  "movie to see, Nudity (Topless), murder, To See, Nudity (Topless - Brief), erlend's DVDs, Below R, In Netflix queue, owned",
#  '70mm, Bibliothek, library, Owned, Oscar (Best Picture), Oscar (Best Directing), drama, Oscar (Best Cinematography), poignant',
#  "Nudity (Topless), Criterion, movie to see, Tumey's DVDs, stylized, atmospheric, National Film Registry, fantasy, adventure",
#  "Betamax, Bibliothek, movie to see, DVD-Video, Futuristmovies.com, National Film Registry, sci-fi, Eric's Dvds, seen",
#  'Bibliothek, National Film Registry, Futuristmovies.com, seen, classic, Nudity (Topless), To See, sci-fi, seen more than once',
#  "Can't remember, atmospheric, tense, comedy, Bibliothek, funny, Disney, classic, disturbing",
#  "70mm, movie to see, quirky, Bibliothek, satirical, irreverent, erlend's DVDs, humorous, disturbing",
#  "Can't remember, Nudity (Topless - Brief), atmospheric, stylized, movie to see, franchise, Criterion, lyrical, assassin",
#  "To See, Can't remember, Nudity (Topless - Brief), Owned, Futuristmovies.com, DVD-Video, sci-fi, Japan, In Netflix queue",
#  "Nudity (Topless - Brief), Betamax, To See, stylized, atmospheric, erlend's DVDs, own, lavish, Oscar (Best Picture)",
#  'Nudity (Topless), Bibliothek, imdb top 250, To See, classic, Disney, Criterion, humorous, Disney animated feature',
#  'stylized, drama, owned, Futuristmovies.com, comedy, DVD-Video, murder, atmospheric, sci-fi',
#  'library, classic, Disney, own, atmospheric, stylized, animation, Disney animated feature, Owned',
#  "library, Can't remember, humorous, Nudity (Topless), quirky, adventure, action, boring, drama",
#  'Nudity (Topless - Brief), drama, classic, adventure, fantasy, humorous, sci-fi, In Netflix queue, tense',
#  "seen more than once, disturbing, movie to see, own, Nudity (Topless), dvd, Can't remember, Disney, Nudity (Full Frontal - Notable)",
#  'Owned, comedy, library, atmospheric, Nudity (Topless - Brief), movie to see, overrated, 70mm, adapted from:book',
#  'seen more than once, classic, dvd, comic book, superhero, adapted from:comic, crime, alter ego, action',
#  'imdb top 250, franchise, disturbing, Owned, dvd, based on a book, seen at the cinema, comedy, funny',
#  'National Film Registry, DVD-Video, In Netflix queue, Owned, stylized, surreal, comic book, adapted from:comic, directorial debut',
#  'based on a book, seen more than once, Betamax, National Film Registry, imdb top 250, Japan, own, USA, Owned',
#  'library, based on a book, owned, imdb top 250, DVD-Video, need to own, seen more than once, dvd, directorial debut',
#  'In Netflix queue, boring, drugs, seen at the cinema, library vhs, action, own, National Film Registry, directorial debut',
#  'directorial debut, In Netflix queue, tense, classic, overrated, Futuristmovies.com, atmospheric, forceful, ummarti2006',
#  'DVD, classic, based on a book, Owned, In Netflix queue, boring, tense, franchise, own',
#  'own, classic, war, true story, library, World War II, stylized, comedy, comic book',
#  'adapted from:book, imdb top 250, murder, bleak, In Netflix queue, comedy, own, disturbing, deliberate',
#  'DVD, dvd, directorial debut, Criterion, murder, seen more than once, Oscar (Best Cinematography), Oscar (Best Directing), stylized',
#  'seen at the cinema, boring, murder, dvd, own, My movies, bittersweet, Nudity (Topless - Notable), based on a play',
#  "In Netflix queue, dvd, humorous, creepy, comedy, Eric's Dvds, VHS, Oscar (Best Picture), owned",
#  "Criterion, Romance, seen at the cinema, romance, chick flick, In Netflix queue, library vhs, classic, Eric's Dvds",
#  'atmospheric, boring, overrated, directorial debut, murder, Criterion, library vhs, religion, satirical',
#  "drama, franchise, In Netflix queue, overrated, fantasy, adapted from:book, superhero, get, Sven's to see list",
#  "action, DVD-Video, Nudity (Topless - Notable), Nudity (Full Frontal - Notable), Oscar (Best Picture), Eric's Dvds, Oscar (Best Directing), murder, reflective",
#  "action, dvd, owned, directorial debut, comedy, Disney, Criterion, Sven's to see list, Disney animated feature",
#  'action, atmospheric, In Netflix queue, based on a book, satirical, Romance, DVD-Video, disturbing, Gfei own it',
#  'directorial debut, seen at the cinema, owned, remake, dvd, action, World War II, comedy, National Film Registry',
#  "quirky, Eric's Dvds, boring, directorial debut, remake, deliberate, disturbing, Owned, netflix",
#  'Criterion, Nudity (Full Frontal - Notable), overrated, drugs, humorous, owned, boring, disturbing, cult film',
#  "Eric's Dvds, funny, dvd, atmospheric, drama, adapted from:play, own, overrated, based on a play",
#  'overrated, World War II, deliberate, Nudity (Full Frontal - Notable), chick flick, Romance, humorous, funny, romance',
#  "Nudity (Full Frontal - Notable), Eric's Dvds, murder, National Film Registry, Drama, AFI 100 (Laughs), humorous, based on a book, poignant",
#  'Nudity (Topless - Notable), imdb top 250, directorial debut, franchise, VHS, Romance, My movies, adapted from:book, TV',
#  'need to own, Nudity (Full Frontal - Notable), overrated, netflix, DVD, Criterion, Nudity (Full Frontal), Below R, imdb top 250',
#  'Nudity (Topless - Notable), boring, quirky, drama, Criterion, atmospheric, seen at the cinema, funny, In Netflix queue',
#  "comedy, Eric's Dvds, overrated, Nudity (Topless - Notable), World War II, Japan, drama, romance, based on book",
#  'netflix, owned, Nudity (Full Frontal - Notable), Bechdel Test:Fail, PG-13, DVD-Video, romance, DVD, chick flick',
#  'Nudity (Full Frontal - Notable), comedy, atmospheric, Drama, library vhs, quirky, remake, true story, drugs',
#  'Nudity (Full Frontal - Notable), tense, deliberate, AFI 100 (Cheers), PG-13, Bechdel Test:Fail, ClearPlay, scope, Nudity (Topless - Notable)',
#  'Nudity (Topless - Notable), quirky, deliberate, true story, bleak, Japan, Criterion, ominous, teen',
#  'family, humorous, New York City, religion, tense, Criterion, seen at the cinema, World War II, Oscar (Best Directing)',
#  "netflix, drugs, boring, AFI 100 (Thrills), library vhs, remake, Drama, Eric's Dvds, AFI 100 (Cheers)",
#  'remake, netflix, Nudity (Topless - Notable), Below R, dvd, VHS, World War II, funny, scope',
#  'true story, based on a play, adapted from:play, overrated, based on book, Biography, Shakespeare, playwright:Shakespeare, AFI 100 (Laughs)',
#  'poignant, directorial debut, Nudity (Full Frontal - Notable), AFI 100 (Movie Quotes), PG-13, war, Japan, Below R, Bechdel Test:Fail',
#  "My movies, Sven's to see list, not corv lib, VHS, poignant, Criterion, Nudity (Rear), cult film, black comedy",
#  'own, Below R, dark, humorous, In Netflix queue, action, Drama, drama, Oscar (Best Picture)',
#  'Below R, disturbing, Potential Oscar Nom, Oscar Nom 2007, Oscar (Best Cinematography), ummarti2006, Nudity (Topless - Notable), Japan, remake',
#  'World War II, based on a play, My movies, Nudity (Full Frontal - Notable), adapted from:play, want to see again, remake, Shakespeare, playwright:Shakespeare',
#  "netflix, Sven's to see list, My movies, Drama, library vhs, DIVX, Nudity (Topless - Notable), AFI 100 (Cheers), murder",
#  'drugs, World War II, CLV, gothic, racism, vhs, VHS, Drama, on dvr',
#  'DIVX, on dvr, politics, DVD, want to see again, Want, VHS, humorous, netflix',
#  'crime, politics, VHS, Japan, talky, Oscar (Best Picture), Oscar (Best Cinematography), Oscar (Best Directing), Below R',
#  "politics, deliberate, My movies, AFI 100 (Laughs), Below R, reflective, Sven's to see list, Nudity (Rear), motorcycle",
#  'Drama, netflix, My movies, religion, corvallis library, drama, VHS, Gfei own it, Nudity (Full Frontal - Notable)',
#  "true story, DIVX, lyrical, PG-13, Sven's to see list, music, not corv lib, romance, musical",
#  'Want, fantasy, library vhs, History, surreal, netflix, remake, boring, forceful',
#  'ummarti2006, own, Drama, CLV, reflective, visceral, R, Gfei own it, Action',
#  'Below R, on dvr, Divx1, religion, Oscar (Best Cinematography), drugs, hilarious, In Netflix queue, cerebral',
#  'My movies, on dvr, Nudity (Full Frontal), aliens, watched 2006, cult film, bleak, directorial debut, deliberate',
#  "drama, hilarious, religion, black and white, music, irreverent, Oscar (Best Actress), Sven's to see list, AFI 100 (Laughs)",
#  'drugs, not corv lib, CLV, 3, netflix, hilarious, World War II, New York City, true story',
#  'DIVX, not corv lib, easily confused with other movie(s) (title), drama, Disney, Action, Below R, understated, watched 2006',
#  'drugs, library vhs, Drama, based on a true story, ClearPlay, need to own, poignant, Nudity (Rear), gothic',
#  "drugs, Below R, sequel, ominous, DIVX, Sven's to see list, Japan, humorous, teen",
#  "Based on a TV show, TV, ClearPlay, Nudity (Rear), gritty, Sven's to see list, netflix, easily confused with other movie(s) (title), franchise",
#  'not corv lib, drugs, black and white, want to see again, DVD-R, New York City, atmospheric, corvallis library, AFI 100 (Cheers)',
#  'not corv lib, Nudity (Rear), Want, on dvr, need to own, Nudity (Full Frontal), Below R, irreverent, drama',
#  'religion, Below R, vhs, very good, on computer, My DVDs, reflective, easily confused with other movie(s) (title), coming of age',
#  'true story, corvallis library, reflective, gay, AFI 100 (Cheers), DIVX, romance, atmospheric, hilarious',
#  'Oscar (Best Cinematography), franchise, Based on a TV show, gothic, R, own, deliberate, TV, violence',
#  'on dvr, franchise, sports, fantasy, Gfei own it, narrated, chick flick, Nudity (Rear), Japan',
#  'bittersweet, crime, talky, AFI 100 (Thrills), watched 2006, Gfei own it, Divx1, religion, ClearPlay',
#  'Nudity (Rear), religion, not corv lib, DIVX, revenge, DVD, adventure, History, bleak',
#  'sports, remake, action, time travel, franchise, dreamlike, lyrical, true story, ClearPlay',
#  'Nudity (Full Frontal), vhs, family, R, Nudity (Rear), irreverent, hilarious, teen, high school',
#  'bleak, want to see again, on computer, CLV, based on book, good, rousing, Below R, downbeat',
#  'easily confused with other movie(s) (title), on computer, Drama, vhs, parody, watched 2006, poignant, directorial debut, AFI 100 (Movie Quotes)',
#  'DVD-R, Drama, menacing, DVD-RAM, gothic, Scary Movies To See on Halloween, true story, overrated, surreal']

# %% [markdown]
# ## Recommendation for a User
#
# The models so far seem to do a pretty good job of suggesting movies similar to a particular movie.  Sometimes, this is all that is needed.  If we notice a user buying a particular movie, we could use this to suggest similar movies they might like.
#
# Often, however, we wish to suggest a movie to a user.  One approach would be to calculate an "average movie" that a particular user enjoyed, and then use the nearest neighbors approach to find movies similar to that one.
#
# To help us judge, we'll add the movie titles to the ratings table.

# %%
df_ratings_title = df_ratings.merge(df[['title']], left_on='movie_id', right_index=True)

# %% [markdown]
# And we'll look at user 9689, who seems to be a fan of horror.

# %%
uid = 9689
df_ratings_title[df_ratings_title.user_id == uid].sort_values('rating', ascending=False)
# Out:
#          movie_id  rating  user_id  \
# 1320721      2367     5.0     9689
# 1320715      1982     5.0     9689
# 1320709      1345     5.0     9689
# 1320708      1339     5.0     9689
# 1320706      1258     5.0     9689
# 1320705      1219     4.0     9689
# 1320717      1994     4.0     9689
# 1320713      1407     4.0     9689
# 1320718      2003     4.0     9689
# 1320716      1991     4.0     9689
# 1320711      1387     4.0     9689
# 1320712      1388     3.0     9689
# 1320720      2160     3.0     9689
# 1320722      2455     3.0     9689
# 1320704      1214     3.0     9689
# 1320710      1347     2.0     9689
# 1320702       382     2.0     9689
# 1320701       366     2.0     9689
# 1320703      1128     2.0     9689
# 1320719      2004     2.0     9689
# 1320714      1970     1.0     9689
# 1320707      1320     1.0     9689
#
#                                                      title
# 1320721                                   King Kong (1976)
# 1320715                                   Halloween (1978)
# 1320709                                      Carrie (1976)
# 1320708             Dracula (Bram Stoker's Dracula) (1992)
# 1320706                                Shining, The (1980)
# 1320705                                      Psycho (1960)
# 1320717                                 Poltergeist (1982)
# 1320713                                      Scream (1996)
# 1320718                                    Gremlins (1984)
# 1320716                                Child's Play (1988)
# 1320711                                        Jaws (1975)
# 1320712                                      Jaws 2 (1978)
# 1320720                             Rosemary's Baby (1968)
# 1320722                                    Fly, The (1986)
# 1320704                                       Alien (1979)
# 1320710                  Nightmare on Elm Street, A (1984)
# 1320702                                        Wolf (1994)
# 1320701                  Wes Craven's New Nightmare (1994)
# 1320703                                    Fog, The (1980)
# 1320719                   Gremlins 2: The New Batch (1990)
# 1320714  Nightmare on Elm Street 3: Dream Warriors, A (...
# 1320707                                      Alien³ (1992)

# %% [markdown]
# We'll compute a weighted average movie, using the scores given as ratings.

# %%
m_locs = df_ratings[df_ratings.user_id == uid]['movie_id'].apply(lambda x: df.index.get_loc(x))
scaled_ratings = df_ratings[df_ratings.user_id == uid]['rating'] * 0.2
weighted_avg_movie = scaled_ratings.reshape(1,-1).dot(features[m_locs,:].toarray()) / len(scaled_ratings)
# Out:
# /home/ariel/miniconda2/envs/pydata/lib/python2.7/site-packages/ipykernel/__main__.py:3: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   app.launch_new_instance()

# %% [markdown]
# And as expected, we get a bunch of horror movies.

# %%
dists, indices = nn.kneighbors(weighted_avg_movie)
df.iloc[indices[0]]
# Out:
#      categories                                              title  year  \
# id
# 4744   [Horror]                            Jeepers Creepers (2001)  2001
# 3843   [Horror]                              Sleepaway Camp (1983)  1983
# 2638   [Horror]                           Mummy's Tomb, The (1942)  1942
# 2636   [Horror]                          Mummy's Ghost, The (1944)  1944
# 2635   [Horror]                          Mummy's Curse, The (1944)  1944
# 2783   [Horror]                         Tomb of Ligeia, The (1965)  1965
# 2868   [Horror]                        Fright Night Part II (1989)  1989
# 2119   [Horror]                           Maximum Overdrive (1986)  1986
# 1349   [Horror]  Nosferatu in Venice (a.k.a. Vampire in Venice)...  1986
# 5844   [Horror]  Prowler, The (a.k.a. Rosemary's Killer) (a.k.a...  1981
# 5766   [Horror]                                      Madman (1981)  1981
# 2655   [Horror]       Howling II: Your Sister Is a Werewolf (1985)  1985
# 1987   [Horror]                                  Prom Night (1980)  1980
# 8854   [Horror]                         Night of the Demons (1988)  1988
# 4514   [Horror]          Howling IV: The Original Nightmare (1988)  1988
# 7120   [Horror]                                    DarkWolf (2003)  2003
# 2634   [Horror]                                  Mummy, The (1959)  1959
# 2516   [Horror]                    Children of the Corn III (1994)  1994
# 2649   [Horror]                         Son of Frankenstein (1939)  1939
# 4518   [Horror]                 Lair of the White Worm, The (1988)  1988
#
#                                                     tag
# id
# 4744                                  [horror, monster]
# 3843                           [monster, penis, tranny]
# 2638          [Scary Movies To See on Halloween, mummy]
# 2636          [Scary Movies To See on Halloween, mummy]
# 2635          [Scary Movies To See on Halloween, mummy]
# 2783  [Scary Movies To See on Halloween, Vincent Pri...
# 2868                                  [cheesy, vampire]
# 2119                                     [stephen king]
# 1349                            [Klaus Kinski, vampire]
# 5844                                          [slasher]
# 5766                                          [slasher]
# 2655            [imdb bottom 100, werewolf, werewolves]
# 1987                                           [remade]
# 8854                                       [possession]
# 4514                             [werewolf, werewolves]
# 7120                           [exploitation, werewolf]
# 2634   [Hammer Film Productions, mummy, Brendan Fraser]
# 2516             [killer child, splatter, killer child]
# 2649                                           [gothic]
# 4518                            [gothic, gothic, pagan]

# %% [markdown]
# ## Cooperative Learning
#
# Content-based recommendation systems work well to find items similar to those a user already likes.  To help with that, we turn to a collaborative learning model.  Instead of finding movies similar to movies a user liked, we will find *users* similar to a given user, and then find the movies that they rated highly.
#
# How do we describe users?  We could use demographic information, but we have better set of features handy: the users' ratings.  Two users are similar if they have rated movies similarly.

# %%
by_user_ratings = df_ratings.groupby('user_id').apply(
    lambda items: {i[1]: i[2] for i in items.itertuples()}) # 0 is index
features = DictVectorizer().fit_transform(by_user_ratings)

# %% [markdown]
# Previously, we have been using the default [Euclidean metric](https://en.wikipedia.org/wiki/Euclidean_distance) in the nearest neighbors calculation:
#
# $$ d(x, y) =  \left| x - y \right|^2 \ . $$
#
# For users, we will instead use the [cosine metric](https://en.wikipedia.org/wiki/Cosine_similarity),
#
# $$ d(x, y) = 1 - \frac{ x\cdot y}{|x|\ |y|} \ , $$
#
# which cares about angles between vectors in feature space.  This dependence on angle only lessens the effect of users using different scales to rate the movies

# %%
nn = NearestNeighbors(n_neighbors=20, metric='cosine', algorithm='brute').fit(features)

# %%
dists, indices = nn.kneighbors(features[by_user_ratings.index.get_loc(uid), :])
neighbors = [by_user_ratings.index[i] for i in indices[0]][1:]
ratings_grp = df_ratings_title[df_ratings_title['user_id'].isin(neighbors)] \
    .groupby('title')['rating']
len(ratings_grp)
# Out:
# 367

# %% [markdown]
# There are a bunch of movies to consider, but we want to pick those that were most enjoyed by the neighbor users.  There's a few ways we might try.
#
# ### Attempt 1: Naive Mean
#
# We could pick those that have the highest average rating, but these are typically movies reviewed by only one or two users.

# %%
ratings_grp.agg(['mean', 'count']).sort_values('mean', ascending=False)
# Out:
#                                                         mean  count
# title
# Dracula (1931)                                      5.000000      1
# Goonies, The (1985)                                 5.000000      1
# Natural Born Killers (1994)                         5.000000      1
# E.T. the Extra-Terrestrial (1982)                   5.000000      2
# Rambling Rose (1991)                                5.000000      1
# Man Bites Dog (C'est arrivé près de chez vous) ...  5.000000      1
# Runaway (1984)                                      5.000000      1
# Legend (1985)                                       5.000000      1
# Kiss the Girls (1997)                               5.000000      1
# Jurassic Park (1993)                                5.000000      1
# Jean de Florette (1986)                             5.000000      1
# Stigmata (1999)                                     5.000000      1
# Hannibal (2001)                                     5.000000      2
# Stand by Me (1986)                                  5.000000      1
# Always (1989)                                       5.000000      1
# Watership Down (1978)                               5.000000      1
# Forrest Gump (1994)                                 5.000000      1
# Double Indemnity (1944)                             5.000000      1
# When Harry Met Sally... (1989)                      5.000000      1
# U-571 (2000)                                        5.000000      1
# Blair Witch Project, The (1999)                     4.666667      3
# Jaws (1975)                                         4.578947     19
# Shining, The (1980)                                 4.500000     18
# Alien (1979)                                        4.500000     18
# Nosferatu (Nosferatu, eine Symphonie des Grauen...  4.500000      2
# Heavenly Creatures (1994)                           4.500000      2
# Bride of Frankenstein (1935)                        4.333333      3
# Nightmare on Elm Street, A (1984)                   4.307692     13
# Poltergeist (1982)                                  4.294118     17
# Halloween (1978)                                    4.266667     15
# ...                                                      ...    ...
# Phantoms (1998)                                     1.666667      3
# Exorcist II: The Heretic (1977)                     1.666667      3
# Bride of Chucky (1998)                              1.666667      3
# Night Flier (1997)                                  1.500000      2
# Phantasm (1979)                                     1.500000      2
# Jaws 3-D (1983)                                     1.500000      4
# Little Shop of Horrors, The (1960)                  1.500000      2
# King Kong Lives (1986)                              1.500000      2
# African Queen, The (1951)                           1.000000      1
# Eye of the Beholder (1999)                          1.000000      1
# Lifeforce (1985)                                    1.000000      1
# Lair of the White Worm, The (1988)                  1.000000      1
# Young Einstein (1988)                               1.000000      1
# Great Balls of Fire! (1989)                         1.000000      1
# Amityville: Dollhouse (1996)                        1.000000      1
# Lost in America (1985)                              1.000000      1
# Vertical Limit (2000)                               1.000000      1
# Deep Impact (1998)                                  1.000000      1
# Fear, The (1995)                                    1.000000      1
# Copycat (1995)                                      1.000000      1
# Amityville II: The Possession (1982)                1.000000      1
# Pink Cadillac (1989)                                1.000000      1
# Harley Davidson and the Marlboro Man (1991)         1.000000      1
# Bats (1999)                                         1.000000      1
# Giant Gila Monster, The (1959)                      1.000000      1
# Body Parts (1991)                                   1.000000      3
# Bill & Ted's Excellent Adventure (1989)             1.000000      1
# Rocketeer, The (1991)                               1.000000      1
# Blind Fury (1989)                                   1.000000      1
# 13 Ghosts (1960)                                    1.000000      1
#
# [367 rows x 2 columns]

# %% [markdown]
# ### Try 2: Naive Sum
#
# Using the sum of the ratings will solve this particular problem, but will tend to highlight only those popular movies that almost everyone has seen.  There's no chance for a movie that's a hit with only some of the neighbors to shine through.

# %%
ratings_grp.agg(['sum', 'count']).sort_values('sum', ascending=False)
# Out:
#                                                      sum  count
# title
# Jaws (1975)                                         87.0     19
# Alien (1979)                                        81.0     18
# Shining, The (1980)                                 81.0     18
# Psycho (1960)                                       80.0     19
# Carrie (1976)                                       76.0     18
# Poltergeist (1982)                                  73.0     17
# Scream (1996)                                       69.0     17
# Halloween (1978)                                    64.0     15
# Exorcist, The (1973)                                59.0     14
# Nightmare on Elm Street, A (1984)                   56.0     13
# Gremlins (1984)                                     52.0     13
# Birds, The (1963)                                   51.0     13
# American Werewolf in London, An (1981)              50.0     13
# Interview with the Vampire: The Vampire Chronic...  47.0     14
# Night of the Living Dead (1968)                     45.0     12
# Dracula (Bram Stoker's Dracula) (1992)              44.0     12
# Omen, The (1976)                                    43.0     11
# Young Frankenstein (1974)                           38.0     10
# Evil Dead II (Dead by Dawn) (1987)                  38.0     10
# Devil's Advocate, The (1997)                        37.0     10
# Thing, The (1982)                                   37.0      9
# From Dusk Till Dawn (1996)                          36.0     10
# Rosemary's Baby (1968)                              36.0     10
# Army of Darkness (1993)                             35.0     10
# Friday the 13th (1980)                              34.0      9
# Ghostbusters (a.k.a. Ghost Busters) (1984)          33.0      8
# Howling, The (1980)                                 31.0      8
# King Kong (1933)                                    29.0      9
# Amityville Horror, The (1979)                       27.0      8
# Fly, The (1986)                                     26.0      7
# ...                                                  ...    ...
# Pet Sematary II (1992)                               2.0      1
# Notorious (1946)                                     2.0      1
# Godzilla (1998)                                      2.0      1
# Hellbound: Hellraiser II (1988)                      2.0      1
# South Pacific (1958)                                 2.0      1
# Going Overboard (1989)                               2.0      1
# Creepshow 2 (1987)                                   2.0      1
# Cyborg (1989)                                        2.0      1
# Haunting, The (1963)                                 2.0      1
# Deep Impact (1998)                                   1.0      1
# Lair of the White Worm, The (1988)                   1.0      1
# Young Einstein (1988)                                1.0      1
# Fear, The (1995)                                     1.0      1
# Bats (1999)                                          1.0      1
# Eye of the Beholder (1999)                           1.0      1
# Bill & Ted's Excellent Adventure (1989)              1.0      1
# Lifeforce (1985)                                     1.0      1
# Harley Davidson and the Marlboro Man (1991)          1.0      1
# Amityville: Dollhouse (1996)                         1.0      1
# Blind Fury (1989)                                    1.0      1
# Giant Gila Monster, The (1959)                       1.0      1
# Rocketeer, The (1991)                                1.0      1
# Pink Cadillac (1989)                                 1.0      1
# Vertical Limit (2000)                                1.0      1
# Great Balls of Fire! (1989)                          1.0      1
# Copycat (1995)                                       1.0      1
# Lost in America (1985)                               1.0      1
# Amityville II: The Possession (1982)                 1.0      1
# African Queen, The (1951)                            1.0      1
# 13 Ghosts (1960)                                     1.0      1
#
# [367 rows x 2 columns]

# %% [markdown]
# ### Try 3: Bayesian Smoothing
#
# One way to balance these two competing needs is to introduce a **Bayesian prior**.  This is the estimate we make that every movie has a rating $\mu$, before seeing any of the user ratings.  As we see ratings from users come it, we formulate a **posterior** estimate of the rating, taking into account both the prior and the new information provided by the ratings.  The posterior estimate of the rating, after seeing the $n$ reviews $\{x_i\}$, can be written as
#
# $$ \frac{ \sum_{i=0}^n x_i + \mu N}{n + N} \ , $$
#
# where $N$ reflects our level of confidence in the prior.  Adjusting $N$ affects the number of user reviews needed to push the posterior estimate away from $mu$.  Adjusting $mu$ affects where in the rankings movies with few reviews appear.  This technique is known as [Bayesian Smoothing](https://en.wikipedia.org/wiki/Additive_smoothing).
#
# In this case, we use $\mu = 3$, $N = 5$, essentially starting each movie off with five reviews of three stars.  The top rated movies are all ones reviewed by our user.  Looking a little bit down the list, we see a recommendation for *The Thing*, which seems very reasonable.  *Ghostbusters* also ranks highly.  This is somewhat surprising, since our user didn't rate any comedies.  Evidently, other fans of horror films like *Ghostbusters* anyway, so maybe our user should give it a try.

# %%
def bayes_sum(N, mu):
    return lambda x: (x.sum() + mu*N) / (x.count() + N)

ratings_grp.aggregate(bayes_sum(5, 3)).sort_values(ascending=False)
# Out:
# title
# Jaws (1975)                                     4.250000
# Shining, The (1980)                             4.173913
# Alien (1979)                                    4.173913
# Poltergeist (1982)                              4.000000
# Psycho (1960)                                   3.958333
# Carrie (1976)                                   3.956522
# Halloween (1978)                                3.950000
# Nightmare on Elm Street, A (1984)               3.944444
# Exorcist, The (1973)                            3.894737
# Scream (1996)                                   3.818182
# Gremlins (1984)                                 3.722222
# Thing, The (1982)                               3.714286
# Ghostbusters (a.k.a. Ghost Busters) (1984)      3.692308
# Birds, The (1963)                               3.666667
# Misery (1990)                                   3.636364
# Omen, The (1976)                                3.625000
# Blair Witch Project, The (1999)                 3.625000
# American Werewolf in London, An (1981)          3.611111
# Hannibal (2001)                                 3.571429
# E.T. the Extra-Terrestrial (1982)               3.571429
# Howling, The (1980)                             3.538462
# Evil Dead II (Dead by Dawn) (1987)              3.533333
# Young Frankenstein (1974)                       3.533333
# Night of the Living Dead (1968)                 3.529412
# Bride of Frankenstein (1935)                    3.500000
# Friday the 13th (1980)                          3.500000
# Frighteners, The (1996)                         3.500000
# Dracula (Bram Stoker's Dracula) (1992)          3.470588
# Devil's Advocate, The (1997)                    3.466667
# Craft, The (1996)                               3.454545
#                                                   ...
# Eye of the Beholder (1999)                      2.666667
# Lifeforce (1985)                                2.666667
# Lair of the White Worm, The (1988)              2.666667
# Cujo (1983)                                     2.666667
# Fear, The (1995)                                2.666667
# Freddy's Dead: The Final Nightmare (1991)       2.666667
# Copycat (1995)                                  2.666667
# Giant Gila Monster, The (1959)                  2.666667
# Great Balls of Fire! (1989)                     2.666667
# Halloween III: Season of the Witch (1982)       2.666667
# Tales from the Hood (1995)                      2.625000
# Bordello of Blood (1996)                        2.625000
# I Still Know What You Did Last Summer (1998)    2.625000
# Friday the 13th Part 3: 3D (1982)               2.600000
# King Kong Lives (1986)                          2.571429
# Little Shop of Horrors, The (1960)              2.571429
# Phantasm (1979)                                 2.571429
# Night Flier (1997)                              2.571429
# Poltergeist III (1988)                          2.555556
# Child's Play 3 (1991)                           2.555556
# Maximum Overdrive (1986)                        2.555556
# Body Snatchers (1993)                           2.545455
# Psycho (1998)                                   2.500000
# Phantoms (1998)                                 2.500000
# Bride of Chucky (1998)                          2.500000
# Amityville 3-D (1983)                           2.500000
# Exorcist II: The Heretic (1977)                 2.500000
# Faculty, The (1998)                             2.444444
# Jaws 3-D (1983)                                 2.333333
# Body Parts (1991)                               2.250000
# Name: rating, dtype: float64

# %% [markdown]
# **Exercises:**
#
# 1. Explore the effect of different distance metrics on the recommendations.  The 'euclidean', 'manhattan', and 'cosine' metrics are some of the more common ones.  Check the `NearestNeighbors` documentation for additional options.
#
# 2. Add in the year as a feature of movies.  Should it be a continuous or categorical variable?  While it's likely that a user who likes movies from 1970 will also like movies from 1971 (suggesting a continuous feature), a user liking movies from 1970 and 1990 is no guarantee that they like movies from 1980 (suggesting a categorical feature).  Can you find an encoding that's in between these two options?  How does the scale of the year, if treated as a continuous feature, affect the KNN calculation?  You may want to use a `StandardScaler`, from `sklearn.preprocessing`, to reduce this effect.
#
# 3. In weighting reviews, we consider not reviewing a movie to be less of a recommendation that scoring it a one.  Shift the rating scale to change this, and see how the affects the resultant recommendations.

# %% [markdown]
# ## Regression of Ratings
#
# We have developed several ways to recommend movies to a user.  However, it is hard to tell how well these systems work, since most users have not rated most movies.  We may return a list of recommendations, none of which has been reviewed by the user.  Is that a sign the user doesn't like those movies, or that they just haven't seen the yet?
#
# An alternative approach is develop a regression model to learn the ratings.  That is, given a user $u$ and an item $i$, we wish to build a model to predict $r_{ui}$, the rating given by $u$ to $i$.  In evaluating the performance of the model, we will consider only user/items pairs where a rating exists.  Our predictions, $\hat r_{ui}$ can be used to determine which unrated items may be preferred by a user.
#
# In order to test how well we can predict rating that haven't been made, we train on only a portion of the data and then evaulate its perfomance on the remainder of the data.  We will take care to use a train-test split.  We will use the root mean-squared error (RMSE) to evaulate our model.  That is, we will compute
#
# $$ \mbox{RMSE} = \sqrt{\frac{1}{n} \sum_{ui} \left(\hat r_{ui} - r_{ui}\right)^2} $$
#
# where $r_{ui}$ are the ratings for $n$ $ui$-pairs in the test set.
#
#
# For the purposes of having code execute quickly for demonstration, we will work with only a small portion of the users.

# %%
users = df_ratings['user_id'].unique()
np.random.seed(42)
user_sample = np.random.choice(users, 3000)
df_ratings_sample = df_ratings[df_ratings['user_id'].isin(user_sample)]
X_train, X_test, y_train, y_test = train_test_split(df_ratings_sample, df_ratings_sample['rating'])

# %% [markdown]
# ## Baseline Model
#
# We start with a baseline model that accounts for the fact that different users and different items will have different baseline scores.  This model has no interaction between the user and item:
#
# $$ b_{ui} = \mu + b_u + b_i \ . $$
#
# This may seem silly to worry about, but the baseline model is very important in practice.  The [winners of the Netflix Grand Prize](http://netflixprize.com/assets/GrandPrize2009_BPC_BellKor.pdf) succeeded largely on the strength of their baseline model.  Alone, it performed nearly as well as the existing Netflix model.
#
# That model included a number of time-dependent terms, but we will consider each of the terms to be constant.  As such $\mu$ will be the average overall rating, $b_u$ will be the average difference from the global mean of all ratings by user $u$, and $b_i$ will be the average difference from the global mean of all ratings of item $i$.  If we one-hot encode both the users and movies, we can find these coefficients with a linear regression.

# %%
class Dictizer(base.BaseEstimator, base.TransformerMixin):
    
    def __init__(self, col):
        self.col = col
    
    def fit(self, X, y=None):
        return self
    
    def transform(self, X):
        return X[self.col].apply(lambda x: {x: 1})

# %%
user_dict = Pipeline([('dict', Dictizer('user_id')),
                      ('vect', DictVectorizer())])
movie_dict = Pipeline([('dict', Dictizer('movie_id')),
                       ('vect', DictVectorizer())])
union = FeatureUnion([('user_dict', user_dict),
                      ('movie_dict', movie_dict)])
lr_pipe = Pipeline([('union', union),
                    ('lr', Ridge(alpha=0))])

# %%
lr_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('union', FeatureUnion(n_jobs=1,
#        transformer_list=[('user_dict', Pipeline(steps=[('dict', Dictizer(col='user_id')), ('vect', DictVectorizer(dtype=<type 'numpy.float64'>, separator='=', sort=True,
#         sparse=True))])), ('movie_dict', Pipeline(steps=[('dict', Dictizer(col='movie_id')...it_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001))])

# %% [markdown]
# A small function will help us calculate RMSE scores.

# %%
def rmse(model, X, y):
    return np.sqrt(mean_squared_error(model.predict(X), y))

# %% [markdown]
# To callibrate our expectations, the RMSE of the mean model is the square root of the variance.

# %%
np.sqrt(y_test.var())
# Out:
# 1.0661338326706293

# %% [markdown]
# Our baseline model does about 18% better.

# %%
rmse(lr_pipe, X_test, y_test)
# Out:
# 0.8798803883612244

# %% [markdown]
# However, our model scores significantly better on the training set.

# %%
rmse(lr_pipe, X_train, y_train)
# Out:
# 0.84778024105566674

# %%
len(lr_pipe.named_steps['lr'].coef_)
# Out:
# 11374

# %% [markdown]
# ## Overfitting and Cross-validation
#
# This discrepancy is a sign that we may be overfitting.  Training data is never perfectly clean.  It contains both the underlying signal, which you want to model, and some random noise, which you do not.  Since our model has over 11K parameters, it has plenty of flexibility to fit the noise as well as the signal.
#
# The noise in this case is the same issue that prompted us to use a Bayesian mean to rate the movies suggested by neighbor users.  Prior to seeing any ratings for a item, for example, we would expect $b_i = 0$.  After seeing a single rating $r$, we shouldn't set $b_i = r - mu$.  Instead, we should update our estimate or $b_i$ somewhat in between these values, depending on our confidence in the prior.
#
# While we could add in these prior ratings by hand, we can use regularization to produce the same effect.  Recall that in ridge regression, we add a term proportional to $\beta^2$ to the quantity being minimized:
#
# $$ \left|y - X\cdot\beta\right|^2 + \alpha\ \left|\beta\right|^2 \ . $$
#
# If the model is being used to take an average, as happens with one-hot encoding, the resultant coefficients will be
#
# $$ \hat\beta_i = \frac{\sum_{j\mid X_{ij}=1} y_j}{n + \alpha} \ , $$
#
# where $n$ is the number of $y_j$ included in the sum.  Note that this is equivalent to our previous Bayesian mean, with $\mu=0$ and $N=\alpha$.  We find the optimal value of $\alpha$ through cross-validation and a grid search.

# %%
gs = GridSearchCV(lr_pipe, {'lr__alpha': np.logspace(-1,1,5)}, n_jobs=-1)

# %% [markdown]
# `GridSearchCV` is itself an estimator.  When it is fit, it will run 3-fold cross validation (by default) on each set of hyperparameters, choose the best set of hyperparameters, and then train the estimator with the best hyperparameters on the full set of data.

# %%
gs.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=None, error_score='raise',
#        estimator=Pipeline(steps=[('union', FeatureUnion(n_jobs=1,
#        transformer_list=[('user_dict', Pipeline(steps=[('dict', Dictizer(col='user_id')), ('vect', DictVectorizer(dtype=<type 'numpy.float64'>, separator='=', sort=True,
#         sparse=True))])), ('movie_dict', Pipeline(steps=[('dict', Dictizer(col='movie_id')...it_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001))]),
#        fit_params={}, iid=True, n_jobs=-1,
#        param_grid={'lr__alpha': array([  0.1    ,   0.31623,   1.     ,   3.16228,  10.     ])},
#        pre_dispatch='2*n_jobs', refit=True, scoring=None, verbose=0)

# %% [markdown]
# We see that performance on the test set has improved somewhat.  (The predict method on the grid search object simply calls predict on the best fit estimator.)

# %%
rmse(gs, X_test, y_test)
# Out:
# 0.87581242845382035

# %% [markdown]
# The best estimator, and its hyperparameter, are available as properties of the grid search object.  (Scikit Learn uses the convention that a trailing underscore indicates a property available only after a model has been fit.)

# %%
best_lr = gs.best_estimator_
gs.best_params_
# Out:
# {'lr__alpha': 3.1622776601683795}

# %%
predict_df = pd.DataFrame({'movie_id': X_train['movie_id'].unique(), 'user_id': 9689})
predict_df = predict_df.merge(df[['title']], left_on='movie_id', right_index=True)
predict_df['scores'] = best_lr.predict(predict_df)
predict_df.sort_values('scores', ascending=False).head(20)
# Out:
#       movie_id  user_id                                              title  \
# 3450      1178     9689                              Paths of Glory (1957)
# 970        858     9689                              Godfather, The (1972)
# 416        318     9689                   Shawshank Redemption, The (1994)
# 2296      5147     9689         Wild Strawberries (Smultronstället) (1957)
# 569        750     9689  Dr. Strangelove or: How I Learned to Stop Worr...
# 2916      4298     9689          Rififi (Du rififi chez les hommes) (1955)
# 1831      2019     9689        Seven Samurai (Shichinin no samurai) (1954)
# 192         50     9689                         Usual Suspects, The (1995)
# 5906      6918     9689               Unvanquished, The (Aparajito) (1957)
# 2339      7767     9689     Best of Youth, The (La Meglio gioventù) (2003)
# 797       1212     9689                              Third Man, The (1949)
# 4121      4928     9689  That Obscure Object of Desire (Cet obscur obje...
# 555        912     9689                                  Casablanca (1942)
# 2402     44555     9689  Lives of Others, The (Das Leben der Anderen) (...
# 181       1221     9689                     Godfather: Part II, The (1974)
# 2480      2360     9689                   Celebration, The (Festen) (1998)
# 4367      8253     9689  Castle Of Cagliostro, The (Rupan sansei: Kario...
# 1685       922     9689      Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)
# 1535      1281     9689                         Great Dictator, The (1940)
# 742       3435     9689                            Double Indemnity (1944)
#
#         scores
# 3450  4.523738
# 970   4.514612
# 416   4.507726
# 2296  4.500447
# 569   4.484474
# 2916  4.471214
# 1831  4.463618
# 192   4.452710
# 5906  4.452701
# 2339  4.446025
# 797   4.438267
# 4121  4.433802
# 555   4.430428
# 2402  4.426217
# 181   4.417363
# 2480  4.416061
# 4367  4.413828
# 1685  4.407906
# 1535  4.404569
# 742   4.402102

# %% [markdown]
# **Exercises:**
#
# 1. Implement another user-item interaction model.  Here are a few ideas:
#    - Measure how similar the user is to fans of the item, and regress against that distance.
#    - Measure how similar the item is to items the user likes, and regress against that distance.
#    - Use a nearest neighbors approach to report the scores given to an item by users similar to the user in question.
#
# 2. Blend two (or more) interaction models together.  These can be different algorithms from (1) or several matrix factorization algorithms with different hyperparameters.  Linear regression is a good way to automatically perform a weighted average together.  The BellKor team had success with **gradient-boosted trees** as blenders.
#
# 3. Add features of the movie or user to the blend.  A nonlinear model, such as **random forest** or gradient-boosted trees, may be able to detect that one of the component models does particularly well for a certain subset of features.

# %% [markdown]
# ## References
#
# - ["Recommendation Systems", from *Mining of Massive Datasets*](http://infolab.stanford.edu/~ullman/mmds/ch9.pdf), by Jure Leskovec, Anand Rajaraman, and Jeff Ullman
# - ["Recommender Systems"](http://vikas.sindhwani.org/recommender.pdf), by Prem Melville and Vinkas Sindhwani
# - [How to Build a Recommendation System](http://www.mickaellegal.com/blog/2014/1/30/how-to-build-a-recommender), by Mickaël Le Gal
# - ["How to Build a Recommender System"](http://blogs.gartner.com/martin-kihn/how-to-build-a-recommender-system-in-python/), by Martin Kihn
# - ["The BellKor Solution to the Netflix Grand Prize"](http://netflixprize.com/assets/GrandPrize2009_BPC_BellKor.pdf), by Yehuda Koren
# - ["Netflix Update: Try This at Home"](http://sifter.org/~simon/journal/20061211.html), by Simon Funk
# - ["Alternating Least Squares Method for Collaborative Filtering"](http://bugra.github.io/work/notes/2014-04-19/alternating-least-squares-method-for-collaborative-filtering/), by Bugra Akyildiz

# %% [markdown]
# *Copyright &copy; 2016 The Data Incubator.  All rights reserved.*
